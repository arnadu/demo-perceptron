# %%
#https://www.gymlibrary.dev/content/environment_creation/
import gym
import gym_examples

import math
import random
import time
import gc

import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
from IPython import display as ipd
from collections import deque

# Import Tensorflow 2.0
import tensorflow as tf
from livelossplot import PlotLosses

from time import sleep
from tqdm import tqdm



#env = gym.make('gym_examples/GridWorld-v0', render_mode='human')
#env = gym.make('gym_examples/PuckWorld-v0', render_mode='human')
#env = gym.make('MountainCar-v0', render_mode='human')
#env = gym.make('CartPole-v1', render_mode='human')

# %%
#def create_rl_model(n_actions):
    
#    model = tf.keras.models.Sequential([
#        tf.keras.layers.Dense(units=32, activation='relu', kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.1)),
#        tf.keras.layers.Dense(units=32, activation='relu', kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.1)),
#        tf.keras.layers.Dense(units=n_actions, activation=None, kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.01))  #returns logits (un-normalized log-proba for each action)
#    ])
#    return model

class DQN(tf.keras.Model):
    """Dense neural network class."""
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        
        kernel_initializer = tf.keras.initializers.TruncatedNormal(mean=0.0, stddev=0.05)
        bias_initializer = tf.keras.initializers.TruncatedNormal(mean=0.0, stddev=0.05)
        
        self.dense1 = tf.keras.layers.Dense(100, activation="relu", kernel_initializer=kernel_initializer, bias_initializer=bias_initializer)
        #self.dense2 = tf.keras.layers.Dense(32, activation="relu", kernel_initializer=kernel_initializer, bias_initializer=bias_initializer)
        self.dense3 = tf.keras.layers.Dense(num_actions, dtype=tf.float32, kernel_initializer=kernel_initializer) # No activation
    
    def call(self, x):
        """Forward pass."""
        x = self.dense1(x)
        #x = self.dense2(x)
        return self.dense3(x)

#a logbook to remember observations, actions and rewards for an entire episode
class Memory:
    def __init__(self, length=0, batch_size=0):
        self.length = length
        self.batch_size = batch_size
        self.clear()
    
    def clear(self):
        self.observations=[]
        self.actions=[]
        self.rewards=[]
        self.dones=[]
        self.next_obs=[]
        
    def add_to_memory(self, obs, action, reward, done, next_obs):
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)
        self.dones.append(done)
        self.next_obs.append(next_obs)
        
        if self.length>0 and len(self.actions)>self.length:
            self.observations.pop(0)
            self.actions.pop(0)
            self.rewards.pop(0)
            self.dones.pop(0)
            self.next_obs.pop(0)
    
    def sample(self):
        if self.batch_size>0:
            i = np.random.randint(0, len(self.actions), self.batch_size) #select a random batch from memory
            o = [self.observations[j] for j in i]
            a = [self.actions[j] for j in i]
            r = [self.rewards[j] for j in i]
            d = [self.dones[j] for j in i]
            no = [self.next_obs[j] for j in i]
            return o,a,r,d,no
        else:
            return self.observations, self.actions, self.rewards, self.dones, self.next_obs
        
    def __len__(self):
        return len(self.actions)

def choose_action(model, observation, num_actions, greedy=True, epsilon=0.):

    if random.uniform(0,1)<epsilon:
        opt = np.random.randint(0, high=num_actions)
        return opt
    else:
        observation_a = tf.expand_dims(observation, axis=0) #assume a single obs is passed, the model expects an array of inputs
        logits = model(observation_a)
        opt = tf.argmax(logits, axis=-1)
        return opt[0].numpy()

# %%
@tf.function
def train_step(target_model, model, observations, actions, rewards, next_observations, dones, gamma):
    
    targets = rewards + gamma * tf.reduce_max( target_model(next_observations), axis=1 )

    with tf.GradientTape() as tape:

        #calculate the Q values; model return the Q values for all possible actions
        #the model returns the Q values of all the actions for each observation
        Q = model(observations)  

        #keep only the Q value of the action that was actually taken
        #idea to use one_hot from https://markelsanz14.medium.com/introduction-to-reinforcement-learning-part-3-q-learning-with-neural-networks-algorithm-dqn-1e22ee928ecd
        mask = tf.one_hot(actions, num_actions) 
        q = tf.math.reduce_sum(mask * Q, axis=1)

        #batch loss is average mean square error
        loss = tf.keras.metrics.mean_squared_error(targets, q)

    grads = tape.gradient(loss, model.trainable_variables)
    #grads, _ = tf.clip_by_global_norm(grads, 2.0)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return loss

# %%
@tf.function
def train_step_clamp(target_model, model, observations, actions, rewards, next_observations, dones, gamma=0.99, td_error_clamp=0):
    
    targets = rewards + gamma * tf.reduce_max( target_model(next_observations), axis=1 )

    with tf.GradientTape() as tape:

        #calculate the Q values; model return the Q values for all possible actions
        #the model returns the Q values of all the actions for each observation
        Q = model(observations)  

        #keep only the Q value of the action that was actually taken
        #idea to use one_hot from https://markelsanz14.medium.com/introduction-to-reinforcement-learning-part-3-q-learning-with-neural-networks-algorithm-dqn-1e22ee928ecd
        mask = tf.one_hot(actions, num_actions) 
        q = tf.math.reduce_sum(mask * Q, axis=1)

        td_err = tf.math.squared_difference(targets,q)
        if td_error_clamp>0:
            td_err = tf.where(tf.math.greater(td_err,td_error_clamp), td_error_clamp, td_err)
        
        #batch loss is average mean square error
        loss = tf.math.reduce_mean(td_err) #tf.keras.metrics.mean_squared_error(targets, q)

    grads = tape.gradient(loss, model.trainable_variables)
    #grads, _ = tf.clip_by_global_norm(grads, 2.0)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return loss

# %%
memory_length = 100000
add_to_experience = 1 #add to experience every N steps
train_period = 1 #number of steps before model is trained
batch_size = 32 #number of steps sampled from experience when training the model

gamma = 0.99
greedy=True
epsilon=0.3
epsilon_halflife = 50
epsilon_min = 0.01
learning_rate = 0.0001
td_error_clamp = 1.

env = gym.make('gym_examples/PuckWorld-v0', reward1=True, reward2=True, render_mode=None, fps=0)  #'human'
#env = gym.make('CartPole-v1', render_mode=None)  #'human'
num_obs = env.observation_space.shape[0]
num_actions = env.action_space.n
#num_actions = 5 #PuckWorld: 0,1,2,3,4 represent left, right, up, down, -, five moves.

model = DQN(num_actions) #create_rl_model(num_actions)
#model.compile()

target_model = DQN(num_actions)
#target_model.compile()

memory = Memory(memory_length, batch_size)  

optimizer = tf.keras.optimizers.Adam(learning_rate)

plotlosses = PlotLosses()

t = 0
log = deque(maxlen=10)  #remember the last 10 episodes to smooth values
log2 = []
# Out:
# C:\Users\remyh\AppData\Roaming\Python\Python38\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
#env._max_episode_steps = 60*10  
max_episode_steps = 60*10  #10sec = 60fps*10''
obs, info = env.reset()
num_episodes = 5000 #
epsilon=0.05
tqdm_episodes = range(num_episodes) #tqdm(range(num_episodes))

truncated = False

for episode in tqdm_episodes:

    obs, info = env.reset()
    episode_score = 0

    #run an episode:
    start_t = t
    while t-start_t < max_episode_steps:

        #tqdm_episodes.set_postfix({'t': t})

        action = choose_action(model, obs, num_actions, greedy=greedy, epsilon=epsilon)
        next_obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        
        episode_score += reward
#        plotlosses.update({'reward': reward})

        if t % add_to_experience == 0:
            memory.add_to_memory(obs, action, reward, done, next_obs)

            
        if len(memory)>=batch_size and t % train_period == 0:

            o,a,r,d,no = memory.sample()

            observations=np.vstack(o)
            actions=np.array(a)
            rewards = np.array(r, dtype=np.float32)
            dones = np.array(d)
            next_observations=np.vstack(no)

            loss = train_step_clamp(target_model, model, observations, actions, rewards, next_observations, dones, gamma=gamma, td_error_clamp=td_error_clamp)

        if done:
            break #out of the episode

#            plotlosses.update({'loss': loss})

        env.render()
        obs = next_obs
        t += 1

    target_model.set_weights(model.get_weights())
    
    #plotlosses.update({'score': episode_score})
    log.append((epsilon, episode_score/(t-start_t)))

    if epsilon > epsilon_min:
        epsilon -= epsilon * math.log(2)/epsilon_halflife

    if episode % len(log) == 0:
        #plotlosses.send()  # draw, update logs, etc
        e_mean = np.mean([e for (e,s) in log])
        s_mean = np.mean([s for (e,s) in log])
        log2.append([e_mean, s_mean])
        print(f'Episode {episode}/{num_episodes}. Epsilon: {epsilon:.3f}. '
            f'Average score in last {len(log)} episodes: {s_mean:.3f}')

    gc.collect()
    
    if truncated:
        break #out of the main loop


env.close()
# Out:
# Episode 0/5000. Epsilon: 0.049. Average score in last 10 episodes: -0.347
# Episode 10/5000. Epsilon: 0.043. Average score in last 10 episodes: -0.327
# Episode 20/5000. Epsilon: 0.037. Average score in last 10 episodes: -0.378
# Episode 30/5000. Epsilon: 0.032. Average score in last 10 episodes: -0.350
# Episode 40/5000. Epsilon: 0.028. Average score in last 10 episodes: -0.343
# Episode 50/5000. Epsilon: 0.025. Average score in last 10 episodes: -0.367
# Episode 60/5000. Epsilon: 0.021. Average score in last 10 episodes: -0.365
# Episode 70/5000. Epsilon: 0.019. Average score in last 10 episodes: -0.334
# Episode 80/5000. Epsilon: 0.016. Average score in last 10 episodes: -0.357
# Episode 90/5000. Epsilon: 0.014. Average score in last 10 episodes: -0.330
# Episode 100/5000. Epsilon: 0.012. Average score in last 10 episodes: -0.318
# Episode 110/5000. Epsilon: 0.011. Average score in last 10 episodes: -0.394
# Episode 120/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.317
# Episode 130/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.436
# Episode 140/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.369
# Episode 150/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.366
# Episode 160/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.398
# Episode 170/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.359
# Episode 180/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.342
# Episode 190/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.349
# Episode 200/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.395
# Episode 210/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.353
# Episode 220/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.353
# Episode 230/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.383
# Episode 240/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.330
# Episode 250/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.306
# Episode 260/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.397
# Episode 270/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.467
# Episode 280/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.364
# Episode 290/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.394
# Episode 300/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.372
# Episode 310/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.363
# Episode 320/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.378
# Episode 330/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.383
# Episode 340/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.324
# Episode 350/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.344
# Episode 360/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.406
# Episode 370/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.437
# Episode 380/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.377
# Episode 390/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.376
# Episode 400/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.357
# Episode 410/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.409
# Episode 420/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.424
# Episode 430/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.372
# Episode 440/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.339
# Episode 450/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.366
# Episode 460/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.432
# Episode 470/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.423
# Episode 480/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.409
# Episode 490/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.369
# Episode 500/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.402
# Episode 510/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.394
# Episode 520/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.419
# Episode 530/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.441
# Episode 540/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.410
# Episode 550/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.385
# Episode 560/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.364
# Episode 570/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.399
# Episode 580/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.396
# Episode 590/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.392
# Episode 600/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.393
# Episode 610/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.492
# Episode 620/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.402
# Episode 630/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.389
# Episode 640/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.345
# Episode 650/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.429
# Episode 660/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.381
# Episode 670/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.467
# Episode 680/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.377
# Episode 690/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.410
# Episode 700/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.370
# Episode 710/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.334
# Episode 720/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.397
# Episode 730/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.421
# Episode 740/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.329
# Episode 750/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.428
# Episode 760/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.433
# Episode 770/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.375
# Episode 780/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.421
# Episode 790/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.388
# Episode 800/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.361
# Episode 810/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.398
# Episode 820/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.386
# Episode 830/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.352
# Episode 840/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.326
# Episode 850/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.345
# Episode 860/5000. Epsilon: 0.010. Average score in last 10 episodes: -0
5000. Epsilon: 0.010. Average score in last 10 episodes: -0.406
# Episode 3930/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.383
# Episode 3940/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.383
# Episode 3950/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 3960/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.451
# Episode 3970/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.407
# Episode 3980/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 3990/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.387
# Episode 4000/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.340
# Episode 4010/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.349
# Episode 4020/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.417
# Episode 4030/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 4040/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.389
# Episode 4050/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.376
# Episode 4060/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.339
# Episode 4070/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.359
# Episode 4080/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.414
# Episode 4090/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 4100/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.366
# Episode 4110/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.348
# Episode 4120/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.393
# Episode 4130/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.402
# Episode 4140/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.398
# Episode 4150/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.377
# Episode 4160/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.355
# Episode 4170/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.385
# Episode 4180/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.402
# Episode 4190/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.370
# Episode 4200/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.338
# Episode 4210/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.361
# Episode 4220/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.342
# Episode 4230/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.405
# Episode 4240/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.431
# Episode 4250/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.451
# Episode 4260/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.426
# Episode 4270/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.420
# Episode 4280/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.358
# Episode 4290/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.408
# Episode 4300/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.328
# Episode 4310/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.382
# Episode 4320/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.418
# Episode 4330/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.318
# Episode 4340/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.396
# Episode 4350/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.377
# Episode 4360/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 4370/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.402
# Episode 4380/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.345
# Episode 4390/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.390
# Episode 4400/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.368
# Episode 4410/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.353
# Episode 4420/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.332
# Episode 4430/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.384
# Episode 4440/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.419
# Episode 4450/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.407
# Episode 4460/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.418
# Episode 4470/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.471
# Episode 4480/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.408
# Episode 4490/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.433
# Episode 4500/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.406
# Episode 4510/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.398
# Episode 4520/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.477
# Episode 4530/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.373
# Episode 4540/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.464
# Episode 4550/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.436
# Episode 4560/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.421
# Episode 4570/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.442
# Episode 4580/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.416
# Episode 4590/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.428
# Episode 4600/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.418
# Episode 4610/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.435
# Episode 4620/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.399
# Episode 4630/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.497
# Episode 4640/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.367
# Episode 4650/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.417
# Episode 4660/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.399
# Episode 4670/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.400
# Episode 4680/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.396
# Episode 4690/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.408
# Episode 4700/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.370
# Episode 4710/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.406
# Episode 4720/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.407
# Episode 4730/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.365
# Episode 4740/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.419
# Episode 4750/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.428
# Episode 4760/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.432
# Episode 4770/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.430
# Episode 4780/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.429
# Episode 4790/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.363
# Episode 4800/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.391
# Episode 4810/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.490
# Episode 4820/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.437
# Episode 4830/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.476
# Episode 4840/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.405
# Episode 4850/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.394
# Episode 4860/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.473
# Episode 4870/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.493
# Episode 4880/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.530
# Episode 4890/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.435
# Episode 4900/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.452
# Episode 4910/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.474
# Episode 4920/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.349
# Episode 4930/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.495
# Episode 4940/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.575
# Episode 4950/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.453
# Episode 4960/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.364
# Episode 4970/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.427
# Episode 4980/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.444
# Episode 4990/5000. Epsilon: 0.010. Average score in last 10 episodes: -0.499

# %%
plt.plot(np.array(log2)[:,0], np.array(log2)[:,1])

# %%
e = [e for (e,s) in log]
s = [s for (e,s) in log]
plt.plot(s)

# %%
# Uncomment following line to save video of our Agent interacting in this environment
# This can be used for debugging and studying how our agent is performing
# env = gym.wrappers.Monitor(env, './video/', force = True)
envh = gym.make('gym_examples/PuckWorld-v0', reward1=True, reward2=True, render_mode='human', fps=60)  #'human'

envh._max_episode_steps = 60*30
t = 0
observation, info = envh.reset()
episode_score=0
while True:
    envh.render()
    t += 1
    #action = env.action_space.sample()
    action = choose_action(model, observation, num_actions, greedy=True, epsilon=0.0)
    observation, reward, terminated, truncated, info = envh.step(action)
    episode_score += reward
    if terminated or truncated:
        observation, info = envh.reset()
        break
print("Episode finished after {} timesteps, score {}".format(t, episode_score/t))
envh.close()
# Out:
# Episode finished after 1908 timesteps, score -0.6097020842233515
