# %%
#https://www.gymlibrary.dev/content/environment_creation/
import gym
import gym_examples

import math
import random
import time
import gc

import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
from IPython import display as ipd
from collections import deque

# Import Tensorflow 2.0
import tensorflow as tf
from livelossplot import PlotLosses

from time import sleep
from tqdm import tqdm



#env = gym.make('gym_examples/GridWorld-v0', render_mode='human')
#env = gym.make('gym_examples/PuckWorld-v0', render_mode='human')
#env = gym.make('MountainCar-v0', render_mode='human')
#env = gym.make('CartPole-v1', render_mode='human')

# %%
#def create_rl_model(n_actions):
    
#    model = tf.keras.models.Sequential([
#        tf.keras.layers.Dense(units=32, activation='relu', kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.1)),
#        tf.keras.layers.Dense(units=32, activation='relu', kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.1)),
#        tf.keras.layers.Dense(units=n_actions, activation=None, kernel_initializer=tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.01))  #returns logits (un-normalized log-proba for each action)
#    ])
#    return model

class DQN(tf.keras.Model):
    """Dense neural network class."""
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        
        kernel_initializer = tf.keras.initializers.TruncatedNormal(mean=0.0, stddev=0.05)
        bias_initializer = tf.keras.initializers.TruncatedNormal(mean=0.0, stddev=0.05)
        
        self.dense1 = tf.keras.layers.Dense(100, activation="relu", kernel_initializer=kernel_initializer, bias_initializer=bias_initializer)
        self.dense2 = tf.keras.layers.Dense(100, activation="relu", kernel_initializer=kernel_initializer, bias_initializer=bias_initializer)
        self.dense3 = tf.keras.layers.Dense(num_actions, dtype=tf.float32, kernel_initializer=kernel_initializer) # No activation
    
    def call(self, x):
        """Forward pass."""
        x = self.dense1(x)
        x = self.dense2(x)
        return self.dense3(x)

#a logbook to remember observations, actions and rewards for an entire episode
class Memory:
    def __init__(self, length=0, batch_size=0):
        self.length = length
        self.batch_size = batch_size
        self.clear()
    
    def clear(self):
        self.observations=[]
        self.actions=[]
        self.rewards=[]
        self.dones=[]
        self.next_obs=[]
        
    def add_to_memory(self, obs, action, reward, done, next_obs):
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)
        self.dones.append(done)
        self.next_obs.append(next_obs)
        
        if self.length>0 and len(self.actions)>self.length:
            self.observations.pop(0)
            self.actions.pop(0)
            self.rewards.pop(0)
            self.dones.pop(0)
            self.next_obs.pop(0)
    
    def sample(self):
        if self.batch_size>0:
            i = np.random.randint(0, len(self.actions), self.batch_size) #select a random batch from memory
            o = [self.observations[j] for j in i]
            a = [self.actions[j] for j in i]
            r = [self.rewards[j] for j in i]
            d = [self.dones[j] for j in i]
            no = [self.next_obs[j] for j in i]
            return o,a,r,d,no
        else:
            return self.observations, self.actions, self.rewards, self.dones, self.next_obs
        
    def __len__(self):
        return len(self.actions)

def choose_action(model, observation, num_actions, greedy=True, epsilon=0.):

    if random.uniform(0,1)<epsilon:
        opt = np.random.randint(0, high=num_actions)
        return opt
    else:
        observation_a = tf.expand_dims(observation, axis=0) #assume a single obs is passed, the model expects an array of inputs
        logits = model(observation_a)
        opt = tf.argmax(logits, axis=-1)
        return opt[0].numpy()

# %%
@tf.function
def train_step(target_model, model, observations, actions, rewards, next_observations, dones, gamma):
    
    targets = rewards + gamma * tf.reduce_max( target_model(next_observations), axis=1 )

    with tf.GradientTape() as tape:

        #calculate the Q values; model return the Q values for all possible actions
        #the model returns the Q values of all the actions for each observation
        Q = model(observations)  

        #keep only the Q value of the action that was actually taken
        #idea to use one_hot from https://markelsanz14.medium.com/introduction-to-reinforcement-learning-part-3-q-learning-with-neural-networks-algorithm-dqn-1e22ee928ecd
        mask = tf.one_hot(actions, num_actions) 
        q = tf.math.reduce_sum(mask * Q, axis=1)

        #batch loss is average mean square error
        loss = tf.keras.metrics.mean_squared_error(targets, q)

    grads = tape.gradient(loss, model.trainable_variables)
    #grads, _ = tf.clip_by_global_norm(grads, 2.0)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return loss

# %%
@tf.function
def train_step_clamp(target_model, model, observations, actions, rewards, next_observations, dones, gamma=0.99, td_error_clamp=0):
    
    targets = rewards + gamma * tf.reduce_max( target_model(next_observations), axis=1 )

    with tf.GradientTape() as tape:

        #calculate the Q values; model return the Q values for all possible actions
        #the model returns the Q values of all the actions for each observation
        Q = model(observations)  

        #keep only the Q value of the action that was actually taken
        #idea to use one_hot from https://markelsanz14.medium.com/introduction-to-reinforcement-learning-part-3-q-learning-with-neural-networks-algorithm-dqn-1e22ee928ecd
        mask = tf.one_hot(actions, num_actions) 
        q = tf.math.reduce_sum(mask * Q, axis=1)

        td_err = tf.math.squared_difference(targets,q)
        if td_error_clamp>0:
            td_err = tf.where(tf.math.greater(td_err,td_error_clamp), td_error_clamp, td_err)
        
        #batch loss is average mean square error
        loss = tf.math.reduce_mean(td_err) #tf.keras.metrics.mean_squared_error(targets, q)

    grads = tape.gradient(loss, model.trainable_variables)
    #grads, _ = tf.clip_by_global_norm(grads, 2.0)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    return loss

# %%
memory_length = 100000
add_to_experience = 1 #add to experience every N steps
train_period = 1 #number of steps before model is trained
batch_size = 32 #number of steps sampled from experience when training the model

gamma = 0.99
greedy=True
epsilon=0.3
epsilon_halflife = 50
epsilon_min = 0.01
learning_rate = 0.0001
td_error_clamp = 1.

env = gym.make('gym_examples/PuckWorld-v0', reward1=True, reward2=True, render_mode=None, fps=0)  #'human'
#env = gym.make('CartPole-v1', render_mode=None)  #'human'
num_obs = env.observation_space.shape[0]
num_actions = env.action_space.n
#num_actions = 5 #PuckWorld: 0,1,2,3,4 represent left, right, up, down, -, five moves.

model = DQN(num_actions) #create_rl_model(num_actions)
#model.compile()

target_model = DQN(num_actions)
#target_model.compile()

memory = Memory(memory_length, batch_size)  

optimizer = tf.keras.optimizers.Adam(learning_rate)

plotlosses = PlotLosses()

t = 0
log = deque(maxlen=10)  #remember the last 10 episodes to smooth values
log2 = []
# Out:
# C:\Users\remyh\AppData\Roaming\Python\Python38\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
#env._max_episode_steps = 60*10  
max_episode_steps = 60*10  #10sec = 60fps*10''
obs, info = env.reset()
num_episodes = 10000 #

epsilon=0.5
epsilon_halflife = 500
epsilon_min = 0.1

tqdm_episodes = range(num_episodes) #tqdm(range(num_episodes))

truncated = False

for episode in tqdm_episodes:

    obs, info = env.reset()
    episode_score = 0

    #run an episode:
    start_t = t
    while t-start_t < max_episode_steps:

        #tqdm_episodes.set_postfix({'t': t})

        action = choose_action(model, obs, num_actions, greedy=greedy, epsilon=epsilon)
        next_obs, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        
        episode_score += reward
#        plotlosses.update({'reward': reward})

        if t % add_to_experience == 0:
            memory.add_to_memory(obs, action, reward, done, next_obs)

            
        if len(memory)>=batch_size and t % train_period == 0:

            o,a,r,d,no = memory.sample()

            observations=np.vstack(o)
            actions=np.array(a)
            rewards = np.array(r, dtype=np.float32)
            dones = np.array(d)
            next_observations=np.vstack(no)

            loss = train_step_clamp(target_model, model, observations, actions, rewards, next_observations, dones, gamma=gamma, td_error_clamp=td_error_clamp)

        if done:
            break #out of the episode

#            plotlosses.update({'loss': loss})

        env.render()
        obs = next_obs
        t += 1

    target_model.set_weights(model.get_weights())
    
    #plotlosses.update({'score': episode_score})
    log.append((epsilon, episode_score/(t-start_t)))

    if epsilon > epsilon_min:
        epsilon -= epsilon * math.log(2)/epsilon_halflife

    if episode % len(log) == 0:
        #plotlosses.send()  # draw, update logs, etc
        e_mean = np.mean([e for (e,s) in log])
        s_mean = np.mean([s for (e,s) in log])
        log2.append([e_mean, s_mean])
        print(f'Episode {episode}/{num_episodes}. Epsilon: {epsilon:.3f}. '
            f'Average score in last {len(log)} episodes: {s_mean:.3f}')

    gc.collect()
    
    if truncated:
        break #out of the main loop


env.close()
# Out:
# Episode 0/10000. Epsilon: 0.499. Average score in last 10 episodes: -0.326
# Episode 10/10000. Epsilon: 0.492. Average score in last 10 episodes: -0.338
# Episode 20/10000. Epsilon: 0.486. Average score in last 10 episodes: -0.413
# Episode 30/10000. Epsilon: 0.479. Average score in last 10 episodes: -0.381
# Episode 40/10000. Epsilon: 0.472. Average score in last 10 episodes: -0.376
# Episode 50/10000. Epsilon: 0.466. Average score in last 10 episodes: -0.386
# Episode 60/10000. Epsilon: 0.459. Average score in last 10 episodes: -0.388
# Episode 70/10000. Epsilon: 0.453. Average score in last 10 episodes: -0.358
# Episode 80/10000. Epsilon: 0.447. Average score in last 10 episodes: -0.374
# Episode 90/10000. Epsilon: 0.441. Average score in last 10 episodes: -0.390
# Episode 100/10000. Epsilon: 0.435. Average score in last 10 episodes: -0.405
# Episode 110/10000. Epsilon: 0.429. Average score in last 10 episodes: -0.338
# Episode 120/10000. Epsilon: 0.423. Average score in last 10 episodes: -0.375
# Episode 130/10000. Epsilon: 0.417. Average score in last 10 episodes: -0.419
# Episode 140/10000. Epsilon: 0.411. Average score in last 10 episodes: -0.323
# Episode 150/10000. Epsilon: 0.406. Average score in last 10 episodes: -0.321
# Episode 160/10000. Epsilon: 0.400. Average score in last 10 episodes: -0.387
# Episode 170/10000. Epsilon: 0.394. Average score in last 10 episodes: -0.427
# Episode 180/10000. Epsilon: 0.389. Average score in last 10 episodes: -0.359
# Episode 190/10000. Epsilon: 0.384. Average score in last 10 episodes: -0.413
# Episode 200/10000. Epsilon: 0.378. Average score in last 10 episodes: -0.390
# Episode 210/10000. Epsilon: 0.373. Average score in last 10 episodes: -0.365
# Episode 220/10000. Epsilon: 0.368. Average score in last 10 episodes: -0.324
# Episode 230/10000. Epsilon: 0.363. Average score in last 10 episodes: -0.365
# Episode 240/10000. Epsilon: 0.358. Average score in last 10 episodes: -0.372
# Episode 250/10000. Epsilon: 0.353. Average score in last 10 episodes: -0.277
# Episode 260/10000. Epsilon: 0.348. Average score in last 10 episodes: -0.390
# Episode 270/10000. Epsilon: 0.343. Average score in last 10 episodes: -0.333
# Episode 280/10000. Epsilon: 0.339. Average score in last 10 episodes: -0.306
# Episode 290/10000. Epsilon: 0.334. Average score in last 10 episodes: -0.354
# Episode 300/10000. Epsilon: 0.329. Average score in last 10 episodes: -0.341
# Episode 310/10000. Epsilon: 0.325. Average score in last 10 episodes: -0.352
# Episode 320/10000. Epsilon: 0.320. Average score in last 10 episodes: -0.348
# Episode 330/10000. Epsilon: 0.316. Average score in last 10 episodes: -0.340
# Episode 340/10000. Epsilon: 0.312. Average score in last 10 episodes: -0.297
# Episode 350/10000. Epsilon: 0.307. Average score in last 10 episodes: -0.343
# Episode 360/10000. Epsilon: 0.303. Average score in last 10 episodes: -0.395
# Episode 370/10000. Epsilon: 0.299. Average score in last 10 episodes: -0.293
# Episode 380/10000. Epsilon: 0.295. Average score in last 10 episodes: -0.298
# Episode 390/10000. Epsilon: 0.291. Average score in last 10 episodes: -0.328
# Episode 400/10000. Epsilon: 0.287. Average score in last 10 episodes: -0.298
# Episode 410/10000. Epsilon: 0.283. Average score in last 10 episodes: -0.358
# Episode 420/10000. Epsilon: 0.279. Average score in last 10 episodes: -0.370
# Episode 430/10000. Epsilon: 0.275. Average score in last 10 episodes: -0.339
# Episode 440/10000. Epsilon: 0.271. Average score in last 10 episodes: -0.380
# Episode 450/10000. Epsilon: 0.267. Average score in last 10 episodes: -0.363
# Episode 460/10000. Epsilon: 0.264. Average score in last 10 episodes: -0.402
# Episode 470/10000. Epsilon: 0.260. Average score in last 10 episodes: -0.350
# Episode 480/10000. Epsilon: 0.257. Average score in last 10 episodes: -0.405
# Episode 490/10000. Epsilon: 0.253. Average score in last 10 episodes: -0.349
# Episode 500/10000. Epsilon: 0.250. Average score in last 10 episodes: -0.339
# Episode 510/10000. Epsilon: 0.246. Average score in last 10 episodes: -0.365
# Episode 520/10000. Epsilon: 0.243. Average score in last 10 episodes: -0.374
# Episode 530/10000. Epsilon: 0.239. Average score in last 10 episodes: -0.284
# Episode 540/10000. Epsilon: 0.236. Average score in last 10 episodes: -0.405
# Episode 550/10000. Epsilon: 0.233. Average score in last 10 episodes: -0.351
# Episode 560/10000. Epsilon: 0.230. Average score in last 10 episodes: -0.357
# Episode 570/10000. Epsilon: 0.226. Average score in last 10 episodes: -0.460
# Episode 580/10000. Epsilon: 0.223. Average score in last 10 episodes: -0.298
# Episode 590/10000. Epsilon: 0.220. Average score in last 10 episodes: -0.315
# Episode 600/10000. Epsilon: 0.217. Average score in last 10 episodes: -0.375
# Episode 610/10000. Epsilon: 0.214. Average score in last 10 episodes: -0.373
# Episode 620/10000. Epsilon: 0.211. Average score in last 10 episodes: -0.340
# Episode 630/10000. Epsilon: 0.208. Average score in last 10 episodes: -0.432
# Episode 640/10000. Epsilon: 0.205. Average score in last 10 episodes: -0.331
# Episode 650/10000. Epsilon: 0.203. Average score in last 10 episodes: -0.401
# Episode 660/10000. Epsilon: 0.200. Average score in last 10 episodes: -0.345
# Episode 670/10000. Epsilon: 0.197. Average score in last 10 episodes: -0.358
# Episode 680/10000. Epsilon: 0.194. Average score in last 10 episodes: -0.315
# Episode 690/10000. Epsilon: 0.192. Average score in last 10 episodes: -0.342
# Episode 700/10000. Epsilon: 0.189. Average score in last 10 episodes: -0.302
# Episode 710/10000. Epsilon: 0.186. Average score in last 10 episodes: -0.354
# Episode 720/10000. Epsilon: 0.184. Average score in last 10 episodes: -0.332
# Episode 730/10000. Epsilon: 0.181. Average score in last 10 episodes: -0.342
# Episode 740/10000. Epsilon: 0.179. Average score in last 10 episodes: -0.304
# Episode 750/10000. Epsilon: 0.176. Average score in last 10 episodes: -0.352
# Episode 760/10000. Epsilon: 0.174. Average score in last 10 episodes: -0.324
# Episode 770/10000. Epsilon: 0.172. Average score in last 10 episodes: -0.334
# Episode 780/10000. Epsilon: 0.169. Average score in last 10 episodes: -0.286
# Episode 790/10000. Epsilon: 0.167. Average score in last 10 episodes: -0.297
# Episode 800/10000. Epsilon: 0.165. Average score in last 10 episodes: -0.310
# Episode 810/10000. Epsilon: 0.162. Average score in last 10 episodes: -0.378
# Episode 820/10000. Epsilon: 0.160. Average score in last 10 episodes: -0.325
# Episode 830/10000. Epsilon: 0.158. Average score in last 10 episodes: -0.307
# Episode 840/10000. Epsilon: 0.156. Average score in last 10 episodes: -0.319
# Episode 850/10000. Epsilon: 0.154. Average score in last 10 episodes: -0.365
# Episode 860/10000. Epsilon: 0.151. Average score in last 10 episodes: -0.357
# Episode 870/10000. Epsilon: 0.149. Average score in last 10 episodes: -0.320
# Episode 880/10000. Epsilon: 0.147. Average score in last 10 episodes: -0.320
# Episode 890/10000. Epsilon: 0.145. Average score in last 10 episodes: -0.293
# Episode 900/10000. Epsilon: 0.143. Average score in last 10 episodes: -0.403
# Episode 910/10000. Epsilon: 0.141. Average score in last 10 episodes: -0.339
# Episode 920/10000. Epsilon: 0.139. Average score in last 10 episodes: -0.349
# Episode 930/10000. Epsilon: 0.137. Average score in last 10 episodes: -0.354
# Episode 940/10000. Epsilon: 0.136. Average score in last 10 episodes: -0.323
# Episode 950/10000. Epsilon: 0.134. Average score in last 10 episodes: -0.352
# Episode 960/10000. Epsilon: 0.132. Average score in last 10 episodes: -0.312
# Episode 970/10000. Epsilon: 0.130. Average score in last 10 episodes: -0.369
# Episode 980/10000. Epsilon: 0.128. Average score in last 10 episodes: -0.316
# Episode 990/10000. Epsilon: 0.126. Average score in last 10 episodes: -0.329
# Episode 1000/10000. Epsilon: 0.125. Average score in last 10 episodes: -0.337
# Episode 1010/10000. Epsilon: 0.123. Average score in last 10 episodes: -0.330
# Episode 1020/10000. Epsilon: 0.121. Average score in last 10 episodes: -0.331
# Episode 1030/10000. Epsilon: 0.120. Average score in last 10 episodes: -0.354
# Episode 1040/10000. Epsilon: 0.118. Average score in last 10 episodes: -0.406
# Episode 1050/10000. Epsilon: 0.116. Average score in last 10 episodes: -0.333
# Episode 1060/10000. Epsilon: 0.115. Average score in last 10 episodes: -0.308
# Episode 1070/10000. Epsilon: 0.113. Average score in last 10 episodes: -0.302
# Episode 1080/10000. Epsilon: 0.112. Average score in last 10 episodes: -0.335
# Episode 1090/10000. Epsilon: 0.110. Average score in last 10 episodes: -0.299
# Episode 1100/10000. Epsilon: 0.109. Average score in last 10 episodes: -0.319
/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.418
# Episode 8940/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.371
# Episode 8950/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.313
# Episode 8960/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.388
# Episode 8970/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.358
# Episode 8980/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.369
# Episode 8990/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.357
# Episode 9000/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.381
# Episode 9010/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.317
# Episode 9020/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.295
# Episode 9030/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.381
# Episode 9040/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.444
# Episode 9050/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.423
# Episode 9060/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.365
# Episode 9070/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.353
# Episode 9080/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.323
# Episode 9090/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.353
# Episode 9100/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.392
# Episode 9110/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.411
# Episode 9120/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.399
# Episode 9130/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.417
# Episode 9140/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.342
# Episode 9150/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.443
# Episode 9160/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.329
# Episode 9170/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.415
# Episode 9180/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.431
# Episode 9190/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.393
# Episode 9200/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.314
# Episode 9210/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.457
# Episode 9220/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.332
# Episode 9230/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.347
# Episode 9240/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.320
# Episode 9250/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.342
# Episode 9260/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.299
# Episode 9270/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.314
# Episode 9280/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.354
# Episode 9290/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.360
# Episode 9300/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.356
# Episode 9310/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.381
# Episode 9320/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.447
# Episode 9330/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.400
# Episode 9340/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.314
# Episode 9350/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.369
# Episode 9360/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.380
# Episode 9370/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.321
# Episode 9380/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.325
# Episode 9390/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.416
# Episode 9400/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.416
# Episode 9410/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.392
# Episode 9420/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.350
# Episode 9430/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.426
# Episode 9440/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.408
# Episode 9450/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.364
# Episode 9460/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.379
# Episode 9470/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.377
# Episode 9480/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.376
# Episode 9490/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.403
# Episode 9500/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.389
# Episode 9510/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.294
# Episode 9520/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.367
# Episode 9530/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.362
# Episode 9540/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.381
# Episode 9550/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.359
# Episode 9560/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.363
# Episode 9570/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.339
# Episode 9580/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.389
# Episode 9590/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.337
# Episode 9600/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.350
# Episode 9610/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.389
# Episode 9620/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.401
# Episode 9630/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.323
# Episode 9640/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.403
# Episode 9650/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.315
# Episode 9660/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.316
# Episode 9670/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.384
# Episode 9680/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.447
# Episode 9690/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.362
# Episode 9700/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.455
# Episode 9710/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.342
# Episode 9720/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.339
# Episode 9730/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.324
# Episode 9740/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.283
# Episode 9750/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.337
# Episode 9760/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.310
# Episode 9770/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.398
# Episode 9780/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.329
# Episode 9790/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.325
# Episode 9800/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.328
# Episode 9810/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.322
# Episode 9820/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.374
# Episode 9830/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.341
# Episode 9840/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.304
# Episode 9850/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.327
# Episode 9860/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.341
# Episode 9870/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.349
# Episode 9880/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.347
# Episode 9890/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.308
# Episode 9900/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.378
# Episode 9910/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.378
# Episode 9920/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.299
# Episode 9930/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.364
# Episode 9940/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.361
# Episode 9950/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.389
# Episode 9960/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.362
# Episode 9970/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.381
# Episode 9980/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.354
# Episode 9990/10000. Epsilon: 0.100. Average score in last 10 episodes: -0.396

# %%
#plt.plot(np.array(log2)[:,0], np.array(log2)[:,1])
plt.plot(np.array(log2)[:,1])

# %%
e = [e for (e,s) in log]
s = [s for (e,s) in log]
plt.plot(s)

# %%
# Uncomment following line to save video of our Agent interacting in this environment
# This can be used for debugging and studying how our agent is performing
# env = gym.wrappers.Monitor(env, './video/', force = True)
envh = gym.make('gym_examples/PuckWorld-v0', reward1=True, reward2=True, render_mode='human', fps=60)  #'human'

envh._max_episode_steps = 60*30
t = 0
observation, info = envh.reset()
episode_score=0
while True:
    envh.render()
    t += 1
    #action = env.action_space.sample()
    action = choose_action(model, observation, num_actions, greedy=True, epsilon=0.0)
    observation, reward, terminated, truncated, info = envh.step(action)
    episode_score += reward
    if terminated or truncated:
        observation, info = envh.reset()
        break
print("Episode finished after {} timesteps, score {}".format(t, episode_score/t))
envh.close()
# Out:
# Episode finished after 3331 timesteps, score -0.5256580404429925
